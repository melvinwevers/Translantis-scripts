# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
input_file = "/users/wevers/alles.csv"

# %%
df = pd.read_csv(input_file, header=0, sep=',', quotechar='"')

# %%
df
# Out:
#        1890-11-28,Passagierslijst.,"Passagiers aan boord van het stoomschip Prins Willem 11, kapt. 3. F. Dörr, vertrokken 27 November van Amsterdam naar West-Indië : A. H. van Baren Scheel», echtg. en kind, J. Wenzel, echtg. en 2 kind., P. Cröger en echtg., M. J. Vink, Graadt van Rogge, A. M. Pos, Ds. J. E. van Duyneveldt, H. J. Wijsman Jz., C. van Lirop, E. Surinamer, H. Kaufmann, Löwenberg."
# 0       1890-11-28,Nederlandsche Stoomvaartlijnen.,"Bu...
# 1       1890-04-05,Gemengd Nieuws.,"Nadat de „kerk"" v...
# 2       1890-05-14,VERSCHEIDENHEDEN.,"Te Parjjs is eon...
# 3       1890-03-29,Feuilleton. CASGAMALA. VAN N. VON E...
# 4       1890-01-29,154,"154  daar beneden, meende de o...
# 5       1890-07-15,Stadsnieuws. Officieele kennisgevin...
# 6       1890-02-28,DE SIGARETTE. NAAR Jules Claretie. ...
# 7       1890-02-05,BUITENLAND. ALGEMEEN OVERZICHT. 4 F...
# 8       1890-05-03,Gemengd Nieuws.,"Ter navolging. De ...
# 9       1890-06-19,"De handelstentoonstelling te Breme...
# 10      1890-06-30,Gemengd Nieuws.,"In Eigen Ha ard is...
# 11      1890-12-14,FEUILLETON. DE BRIEF.,"I. Het was o...
# 12      1890-07-12,Ingezonden.,"Mijnheer de Redacteur!...
# 13      1890-01-21,INGEZONDEN STUKKEN.,"Aan de Bedacti...
# 14      1890-03-01,DE SIGARETTE. d) NAAE Jules Claretl...
# 15      1890-01-25,In vochtige streken zijn de lijders...
# 16      1890-01-24,FEUILLETON. Dagdieven of Arbeiders?...
# 17      1890-11-21,WELDADIGHEID.,"Vereen. „Weldadighei...
# 18      1890-07-23,Stadsnieuws. Officieele Kennisgevin...
# 19      1890-08-15,Allerlef. De cholera.,"In Valencia ...
# 20      1890-02-27,DE SIGARETTE. KAAR Jules Claretle. ...
# 21      1890-12-05,Keuring van voedingsmiddelen.,"Het ...
# 22      1890-03-21,ALLERLEI.,"Volgens den Sport-Almana...
# 23      1890-01-18,INGEBONDEN MEDEDEELINGEN à 55 cent ...
# 24      1890-05-17,Van den Koning en Zijn Huis.,"Met g...
# 25      1890-05-19,INGEZONDEN MEDEDEELINGEN a 55 cent ...
# 26      1890-09-11,Parijsche echo's.,"LXX.  Terwijl ik...
# 27      1890-07-16,"Amsterdam, 15 Juli. Een bezoek bij...
# 28      1890-01-18,Ingezonden.,"Mijnheer de Redacteur....
# 29      1890-07-28,Staats-Courant.,"Rcnoemd is in de o...
# ...                                                   ...
# 184973  1989-01-10,Australië,"Kijk eens wat een land a...
# 184974  1989-06-07,Van Stolk en Rees Europese voorpost...
# 184975  1989-06-02,Wondermiddelen op braderie Drachten...
# 184976  1989-07-10,Drie kartonfabrieken Bührmann gaan ...
# 184977  1989-10-13,Experimenten,"Verder is 'sampling' ...
# 184978  1989-04-10,Drang,"Na een paar maanden zag Fiel...
# 184979  1989-04-04,Matras,"• Roken is slecht voor je g...
# 184980  1989-12-23,België RTBF,"15.30 Ecran des vacanc...
# 184981  1989-06-08,Rooks openhartig in 'levensverhaal'...
# 184982  1989-07-29,De overval op BAT-Industries f 45.0...
# 184983  1989-05-22,"Dertiende lustrum van 'Artsen-Auto...
# 184984  1989-02-10,Met Marleen valt niet te spotten Ne...
# 184985  1989-09-21,Kleur in de winteretalage,"Alison B...
# 184986  1989-06-09,'Wij houden niet van handelsbelemme...
# 184987  1989-08-17,De biefstuk inflatie in Joegoslavië...
# 184988  1989-11-21,Martelende meisjes tot 15 maanden v...
# 184989  1989-05-23,Sympathie jonge militairen vaar sta...
# 184990  1989-12-12,Unicef: Vooruitzichten voor kindere...
# 184991  1989-03-29,SNACKWAGEN - Vele dozen,"SNACKWAGEN...
# 184992  1989-10-27,Aanvoer Klaver Vier steeg met 9 pro...
# 184993  1989-06-10,Sandalen,"Binoer werd voor zes maan...
# 184994  1989-01-30,Poolse film met Amerikaans budget P...
# 184995  1989-10-16,"Door Rein Wolters Reacties op deze...
# 184996  1989-09-11,De steden,"Workum verduitst ook al,...
# 184997  1989-12-29,GGD helpt zware rokers afkicken Doo...
# 184998  1989-05-11,A-sociaal Door Thea Beekman,"Volgen...
# 184999  1989-05-13,Even pauze,"FOTO AP Een inwoner van...
# 185000  1989-05-02,'Misschien breng ik hem gewoon weg....
# 185001  1989-01-18,uit JOURNAAL,"AVPWO6UDB&lt; COWBIKA...
# 185002  1989-06-14,uit JOURNAAL,"Evita in Schouwburg H...
#
# [185003 rows x 1 columns]

# %%
df.text = df["text_content"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-5b2921c8ad2b> in <module>()
# ----> 1 df.text = df["text_content"]
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/index.py in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'text_content'

# %%
countvec = CountVectorizer(stop_words ='dutch', max_df=0.95, min_df=0.01)

# %%
dtm = countvec.fit_transform(df.text)

# %%
 df = pd.DataFrame(x1.toarray().transpose(), index = vectorizer.get_feature_names())
