# %%
# %matplotlib inline
import csv
import collections
import pprint
import sys
import pandas as pd
import matplotlib
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show
from sklearn_pandas import DataFrameMapper, cross_val_score
import sklearn.preprocessing, sklearn.decomposition, sklearn.linear_model, sklearn.pipeline, sklearn.metrics

# %%
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
main_file = "/Users/wevers/Data/trust.csv"

# %%
single = pd.read_csv(main_file, header=0, sep='\t', names = ["date", "newspaper", "title", "content"])
#data = data.set_index(pd.DatetimeIndex(data['paper_dc_date']))

# %%
single = df.drop_duplicates(['title']) #remove duplicate articles based on article title
df2 = df.drop_duplicates(['title']) #remove duplicate articles based on article title

# %%
single['newspaper'] = single['newspaper'].apply(lambda x: x.split(':')[0]) #strip cell after :
single['newspaper'] = single['newspaper'].apply(lambda x: x.split('/')[0]) #strip cell after /
single['newspaper'] = single['newspaper'].str.lower().str.replace('ĳ', 'ij') #fix error with ij
single['content'] = single['content'].str.lower() #lower-case text content
single = single.dropna()

# %%
single = single[single['content'].str.contains("aandelen") == False]
single = single[single['content'].str.contains("sollicitatie") == False]
single = single[single['content'].str.contains("gevraagd") == False]
single = single[single['content'].str.contains("salaris") == False]
single = single[single['content'].str.contains("ervaring") == False]
single = single[single['content'].str.contains("opleiding") == False]
single = single[single['content'].str.contains("puzzelactie") == False]

# %%
single = single[single['content'].str.contains("margarine") == False]
single = single[single['content'].str.contains("unox") == False]
single = single[single['content'].str.contains("calvé") == False]
single = single[single['content'].str.contains("mayonaise") == False]
single = single[single['content'].str.contains("pindakaas") == False]

# %%
single.to_csv('CorpusB.csv', index=False) #export to csv

# %%
single
# Out:
#             date                     newspaper        title  \
# 0     1987-10-01                  de telegraaf  Advertentie
# 1     1956-08-18                      de tijd   Advertentie
# 2     1954-12-23                      de tijd   Advertentie
# 3     1984-12-21    nieuwsblad van het noorden  Advertentie
# 4     1984-12-19                  de telegraaf  Advertentie
# 5     1957-07-05                  de telegraaf  Advertentie
# 6     1955-01-15                      de tijd   Advertentie
# 7     1955-04-16            limburgsch dagblad  Advertentie
# 8     1956-06-23                  de telegraaf  Advertentie
# 9     1950-01-14                      de tijd   Advertentie
# 10    1972-02-26                  de telegraaf  Advertentie
# 11    1979-03-14               het vrije volk   Advertentie
# 12    1960-11-25                  de telegraaf  Advertentie
# 13    1960-12-02                  de telegraaf  Advertentie
# 14    1980-09-05  nieuw israelietisch weekblad  Advertentie
# ...

# %%
 pd.Series(' '.join(single['content']).lower().split()).value_counts()[100:500]
# Out:
# 500             349
# smaak           348
# maar            347
# nog             345
# drank           340
# t.k.            333
# wordt           332
# fl              330
# naar            330
# k               326
# na              318
# worden          317
# blik            315
# nederland       314
# 11              313
# 8               313
# &gt;            308
# pak             303
# ..              303
# geen            297
# nieuwe          294
# dag             292
# 't              291
# &amp;           290
# grote           285
# c.              282
# 30              276
# n.v.            270
# gebotteld       269
# »               268
#                ...
# 69               69
# genoeg           69
# uur,             69
# staat            69
# gij              69
# dezelfde         69
# §                68
# koffie           68
# tussen           68
# venda            68
# heden            68
# and              67
# gezinsfles       67
# millioen         67
# ...

# %%
threshold = 25 # Anything that occurs less than this will be removed.
value_counts = single['newspaper'].value_counts()
to_remove = value_counts[value_counts <= threshold].index
single['newspaper'].replace(to_remove, inplace=True)

# %%
matplotlib.rcParams.update({'font.size': 15})
plt.gcf().subplots_adjust(bottom=0.50)
plot = single['newspaper'].value_counts().plot(kind="bar") #plot newspaper_titles

# %%
fig = plot.get_figure() #export plot to PNG file
fig.set_size_inches(15, 15)
fig.tight_layout()
fig.subplots_adjust(bottom=0.25)
fig.savefig('Coca-Cola-CorpusB_ads.pdf', format='pdf', dpi=1000)

# %%
single['merged'] = single['title'].map(str) + single['content'].map(str)

# %%
single
# Out:
#              date                              newspaper  \
# 0      1984-06-16                           de telegraaf
# 1      1957-11-26                            de waarheid
# 2      1941-12-30             dagelijksche beurscourant
# 3      1906-01-25             nieuwe tilburgsche courant
# 4      1964-05-29                    leeuwarder courant
# 5      1964-08-20                            de waarheid
# 6      1964-02-15                    de tijd de maasbode
# 7      1947-03-05             nieuwsblad van het zuiden
# 8      1978-06-30           nieuw israelietisch weekblad
# 9      1971-06-19                           de telegraaf
# 10     1954-09-29                            de waarheid
# 11     1980-03-05                    nederlands dagblad
# 12     1971-06-07                            de waarheid
# 13     1986-12-03                           de telegraaf
# 14     1986-11-29                           de telegraaf
# ...
