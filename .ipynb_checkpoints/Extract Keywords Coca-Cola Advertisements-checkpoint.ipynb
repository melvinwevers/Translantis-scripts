# %%
# %matplotlib inline
import csv
import collections
import pprint
import sys
import pandas as pd
import matplotlib
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
from pylab import figure, axes, pie, title, show
from sklearn_pandas import DataFrameMapper, cross_val_score
import sklearn.preprocessing, sklearn.decomposition, sklearn.linear_model, sklearn.pipeline, sklearn.metrics

# %%
n_articles = 192

# %%
main_file = "/Users/wevers/Data/coca-cola_ads/1928-1937.txt"

# %%
df = pd.read_csv(main_file, header=0, sep=',', names = ["date","title", "content"])
#data = data.set_index(pd.DatetimeIndex(data['paper_dc_date']))

# %%
df['content'] = df['content'].str.lower()

# %%
word_regexs = [r'alcohol',
               r'apart*',
               r'aroma',
               r'best*',
               r'bijzonder*',
               r'[a-z]alorie*',
               r'chique',
               r'dagelijks',
               r'dorst',
               r'echte',
               r'extra',
               r'fijn',
               r'fles*',
               r'fris',
               r'gezellig*',
               r'gezinsfles*',
               r'glas',
               r'glazen',
               r'heerlijk',
               r'iedereen',
               r'kenner*',
               r'king?size',
               r'kingsize',
               r'kroonkurk*',
               r'kwaliteit',
               r'landen',
               r'lekker*',
               r'lescht',
               r'light',
               r'lijn',
               r'literfles*',
               r'modern*',
               r'mondain*',
               r'nieuw*',
               r'ontworpen',
               r'onvervangbare',
               r'opgewerkt*',
               r'opwekkend*',
               r'origine[a-z]*',
               r'overal',
               r'parel*',
               r'pauze',
               r'plastic',
               r'populair*',
               r'praktisch*',
               r'prijs',
               r'samenstelling',
               r'sierlijk*',
               r'smaak',
               r'sprankelen*',
               r'standaardfles*',
               r'stimuleer*',
               r'verfris*',
               r'verkrijgbaar',
               r'verkwik*',
               r'verukkelijk*',
               r'voordelig*',
               r'vruchten*',
               r'wereld',
               r'zuiver*',
               r'mil[a-z]oen*',
            ]

# %%
rel_counts = pd.Series((df['content'].str.contains(r).sum() / n_articles * 100 for r in word_regexs), word_regexs, name='rel_count')
abs_counts = pd.Series((df['content'].str.contains(r).sum() for r in word_regexs), word_regexs, name='abs_count')

# %%
abs_counts
# Out:
# alcohol            39
# apart*            106
# aroma              40
# best*              99
# bijzonder*         57
# [a-z]alorie*        0
# chique             24
# dagelijks          95
# dorst              96
# echte               9
# extra               4
# fijn               81
# fles*             100
# fris              107
# gezellig*           5
# gezinsfles*         0
# glas               97
# glazen             98
# heerlijk          129
# iedereen            6
# kenner*            47
# king?size           0
# kingsize            0
# kroonkurk*          0
# kwaliteit          20
# landen             65
# lekker*             4
# lescht             32
# light               0
# lijn                6
#                  ...
# modern*            34
# mondain*           19
# nieuw*             45
# ontworpen           0
# onvervangbare       0
# opgewerkt*          0
# opwekkend*         43
# origine[a-z]*       3
# overal             83
# parel*             21
# pauze               2
# plastic             0
# populair*          41
# praktisch*          0
# prijs              32
# samenstelling      36
# sierlijk*           3
# smaak             137
# sprankelen*         9
# standaardfles*      0
# stimuleer*         18
# verfris*           99
# verkrijgbaar       84
# verkwik*           15
# verukkelijk*        2
# voordelig*          0
# vruchten*         107
# wereld             69
# zuiver*            43
# mil[a-z]oen*        4
# Name: abs_count, dtype: int64

# %%
rel_counts = counts.round(1)

# %%
wordcount = pd.concat([rel_counts, abs_counts], axis=1)

# %%
wordcount
# Out:
#                 rel_count  abs_count  abs_count  abs_count
# alcohol              20.3         39         39         39
# apart*               55.2        106        106        106
# aroma                20.8         40         40         40
# best*                51.6         99         99         99
# bijzonder*           29.7         57         57         57
# [a-z]alorie*          0.0          0          0          0
# chique               12.5         24         24         24
# dagelijks            49.5         95         95         95
# dorst                50.0         96         96         96
# echte                 4.7          9          9          9
# extra                 2.1          4          4          4
# fijn                 42.2         81         81         81
# fles*                52.1        100        100        100
# fris                 55.7        107        107        107
# gezellig*             2.6          5          5          5
# gezinsfles*           0.0          0          0          0
# glas                 50.5         97         97         97
# glazen               51.0         98         98         98
# heerlijk             67.2        129        129        129
# iedereen              3.1          6          6          6
# kenner*              24.5         47         47         47
# king?size             0.0          0          0          0
# kingsize              0.0          0          0          0
# kroonkurk*            0.0          0          0          0
# kwaliteit            10.4         20         20         20
# landen               33.9         65         65         65
# lekker*               2.1          4          4          4
# lescht               16.7         32         32         32
# light                 0.0          0          0          0
# lijn                  3.1          6          6          6
# ...                   ...        ...        ...        ...
# modern*              17.7         34         34         34
# mondain*              9.9         19         19         19
# nieuw*               23.4         45         45         45
# ontworpen             0.0          0          0          0
# onvervangbare         0.0          0          0          0
# opgewerkt*            0.0          0          0          0
# opwekkend*           22.4         43         43         43
# origine[a-z]*         1.6          3          3          3
# overal               43.2         83         83         83
# parel*               10.9         21         21         21
# pauze                 1.0          2          2          2
# plastic               0.0          0          0          0
# populair*            21.4         41         41         41
# praktisch*            0.0          0          0          0
# prijs                16.7         32         32         32
# samenstelling        18.8         36         36         36
# sierlijk*             1.6          3          3          3
# smaak                71.4        137        137        137
# sprankelen*           4.7          9          9          9
# standaardfles*        0.0          0          0          0
# stimuleer*            9.4         18         18         18
# verfris*             51.6         99         99         99
# verkrijgbaar         43.8         84         84         84
# verkwik*              7.8         15         15         15
# verukkelijk*          1.0          2          2          2
# voordelig*            0.0          0          0          0
# vruchten*            55.7        107        107        107
# wereld               35.9         69         69         69
# zuiver*              22.4         43         43         43
# mil[a-z]oen*          2.1          4          4          4
#
# [61 rows x 4 columns]

# %%
counts.to_csv('keywords_1928-1937.csv') #export to csv

# %%
counts
# Out:
#                 count  abs_count  abs_count
# [a-z]alorie*      2.4          0          0
# alcohol           0.8         39         39
# apart*            2.7        106        106
# aroma             1.9         40         40
# best*            34.3         99         99
# bijzonder*        3.5         57         57
# chique            0.5         24         24
# dagelijks         6.2         95         95
# dorst             0.8         96         96
# echte             9.1          9          9
# extra            18.5          4          4
# fijn             11.3         81         81
# fles*            34.6        100        100
# fris              7.8        107        107
# gezellig*         4.6          5          5
# gezinsfles*       0.0          0          0
# glas             16.4         97         97
# glazen            5.1         98         98
# heerlijk          4.8        129        129
# iedereen          2.4          6          6
# kenner*           1.9         47         47
# king?size         0.0          0          0
# kingsize          0.0          0          0
# kroonkurk*        0.0          0          0
# kwaliteit        10.5         20         20
# landen            2.4         65         65
# lekker*          13.1          4          4
# lescht            0.0         32         32
# light            13.9          0          0
# lijn              8.8          6          6
# ...               ...        ...        ...
# mil[a-z]oen*      NaN          4          4
# modern*           NaN         34         34
# mondain*          0.0         19         19
# nieuw*           35.7         45         45
# ontworpen         0.0          0          0
# onvervangbare     0.0          0          0
# opgewerkt*        0.0          0          0
# opwekkend*        0.0         43         43
# origine[a-z]*     4.0          3          3
# overal            2.7         83         83
# parel*            4.3         21         21
# pauze             0.5          2          2
# plastic           2.1          0          0
# populair*         1.1         41         41
# praktisch*        0.0          0          0
# prijs            27.9         32         32
# samenstelling     0.0         36         36
# sierlijk*         0.3          3          3
# smaak             5.9        137        137
# sprankelen*       0.3          9          9
# standaardfles*    0.0          0          0
# stimuleer*        0.0         18         18
# verfris*          1.1         99         99
# verkrijgbaar      3.5         84         84
# verkwik*          0.0         15         15
# verukkelijk*      0.0          2          2
# voordelig*        6.2          0          0
# vruchten*         5.4        107        107
# wereld            4.0         69         69
# zuiver*           3.2         43         43
#
# [62 rows x 3 columns]
